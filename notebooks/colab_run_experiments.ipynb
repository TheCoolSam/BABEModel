# %% [markdown]
# # Dynamic-BABE — Colab experiment runner
#
# Closing your **laptop** is fine while Colab runs in the cloud. Free Colab may still disconnect idle sessions; prefer Colab Pro or SSH/`tmux` (`scripts/remote_tmux.sh`) for multi-hour jobs.
#
# Upload or clone this repository, then run the cells below.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
import os
REPO = os.environ.get('BABE_REPO', '/content/polarizationParadox')
if os.path.isdir(REPO):
    os.chdir(REPO)
else:
    print('Set BABE_REPO / REPO to your clone path')
# %pip install -q -r requirements.txt
print('cwd:', os.getcwd())

# %%
# !python -m experiments.ablations --iters=20 --workers=2

# %%
# !python -m experiments.baselines --iters=20 --workers=2
# !python -m experiments.topology_robustness --iters=15 --workers=2
print('Done. Final CSVs in output/; checkpoints in output/checkpoints/.')
